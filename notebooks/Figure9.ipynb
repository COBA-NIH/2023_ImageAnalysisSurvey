# %%
#importing the necessary modules
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import numpy as np
import plotly.io as pio
import kaleido
from wordcloud import WordCloud, STOPWORDS
from utils import *

# %load_ext autoreload
# %autoreload 2

# %%
#reading data from main notebook 
# %store -r data

# %% [markdown]
# ##### Creating the dataframes

# %% [markdown]
# ##### Creators role

# %%
# Creating new columns for categorization 
# creating a column for work type
data.loc[data["Work description"] < 3, "Work type" ] = "Imaging"
data.loc[(data["Work description"] >= 3) & (data["Work description"] <= 5), "Work type"] = "Balanced"
data.loc[data["Work description"] > 5, "Work type"] = "Analyst"

# %%
#Creating a dataframe for creators role from imaging participants
creator_role_based = data.loc[:, ['Creators role', 'Work type']]
creator_role_based = creator_role_based.dropna()
creator_role_based= creator_role_based.groupby('Work type')
creator_imaging = creator_role_based.get_group('Imaging')
creator_imaging = creator_imaging.rename(columns={'Creators role':'Creators role-Imaging'})
#creator_imaging.to_csv('C:\\Users\\ssivagur\\Documents\\GitHub\\2023_ImageAnalysisSurvey\\csv files\\creator_imaging.csv')

# %%
#Creating a dataframe for creators role from balanced participants
creator_balanced = creator_role_based.get_group('Balanced')
creator_balanced = creator_balanced.rename(columns={'Creators role':'Creators role- Balanced'})
#creator_balanced.to_csv('C:\\Users\\ssivagur\\Documents\\GitHub\\2023_ImageAnalysisSurvey\\csv files\\creator_balanced.csv')

# %%
#Creating a dataframe for creators role from analyst 
creator_analyst = creator_role_based.get_group('Analyst')
creator_analyst = creator_analyst.rename(columns={'Creators role':'Creators role-Analyst'})
#creator_analyst.to_csv('C:\\Users\\ssivagur\\Documents\\GitHub\\2023_ImageAnalysisSurvey\\csv files\\creator_analyst.csv')

# %% [markdown]
# ##### Users role

# %%
# Grouping based on work type and users role 
user_role_based = data.loc[:, ['Users role', 'Work type']]
user_role_based = user_role_based.dropna()
user_role_based= user_role_based.groupby('Work type')

user_role_imaging = user_role_based.get_group('Imaging')
user_role_imaging =user_role_imaging.rename(columns={'Users role':'Users role - Imaging'})
#user_role_imaging.to_csv('C:\\Users\\ssivagur\\Documents\\GitHub\\2023_ImageAnalysisSurvey\\csv files\\user_role_imaging.csv')

# %%
#creating dataframe for the 'Users role-Balanced'
user_role_balanced = user_role_based.get_group('Balanced')
user_role_balanced = user_role_balanced.rename(columns ={'Users role':'Users role-Balanced'})
#user_role_balanced.to_csv('C:\\Users\\ssivagur\\Documents\\GitHub\\2023_ImageAnalysisSurvey\\csv files\\user_role_balanced.csv')

# %%
#Users role - Analyst
user_role_analyst = user_role_based.get_group('Analyst')
user_role_analyst = user_role_analyst.rename(columns={'Users role':'Users role - Analyst'})
#user_role_analyst.to_csv('C:\\Users\\ssivagur\\Documents\\GitHub\\2023_ImageAnalysisSurvey\\csv files\\user_role_analyst.csv')

# %% [markdown]
# ##### Wordclouds

# %% [markdown]
# ##### Creators role - imaging

# %%
wordcloud_50(creator_imaging["Creators role-Imaging"], extra_stopwords=['tool','make','analysis', 'better', 'more', 'software', 'tools', 'user', 'step', 'users', 'use', 'image', 'don', 't', 's', 'etc', 
                 'used', 'clearly', 'doesn', 'best', 'touch', 'give', 'non', 'less', 'images', 'asap', 'high','using', 'well', 'work', 'even', 'end',
                 'others','everyone','everything','know','really','without','something','always','one','want', 'exactly', 've','m','certain', 're','instead',
                 'us','maybe','sc', 'kind','going', 'different','see','especially', 'lack','much', 'past', 'selves', 'running', 'either','require', 'happens', 'lot', 'put', 'perhaps', 
                 'properly', 'many', 'behave', 'good', 'data', 'away', 'tell', 'will'])
# Out:
# c:\Users\ssivagur\Documents\GitHub\2023_ImageAnalysisSurvey\notebooks\utils.py:294: FutureWarning: The default value of regex will change from True to False in a future version.
#   input = ''.join(series.str.lower().str.split().dropna(how='all').astype(str).str.replace(r'[-./?!,":;()\']',' ')) #splitting the strings and replacing the spaces or special characters

# %% [markdown]
# ##### Creators role - balanced

# %%
wordcloud_50(creator_balanced['Creators role- Balanced'], extra_stopwords=['tool','make','analysis', 'better', 'more', 'software', 'tools', 'user', 'step', 'users', 'use', 'image', 'don', 't', 's', 'etc', 
                 'used', 'clearly', 'doesn', 'best', 'touch', 'give', 'non', 'less', 'images', 'asap', 'high','using', 'well', 'work', 'even', 'end',
                 'others','everyone','everything','know','really','without','something','always','one','want', 'exactly', 've','m','certain', 're','instead',
                 'us','maybe','sc', 'kind','going', 'different','see','especially', 'lack','much', 'past', 'selves', 'running', 'either','require', 'happens', 'lot', 'put', 'perhaps', 
                 'properly', 'many', 'behave', 'good', 'data', 'away', 'tell', 'will'])
# Out:
# c:\Users\ssivagur\Documents\GitHub\2023_ImageAnalysisSurvey\notebooks\utils.py:294: FutureWarning: The default value of regex will change from True to False in a future version.
#   input = ''.join(series.str.lower().str.split().dropna(how='all').astype(str).str.replace(r'[-./?!,":;()\']',' ')) #splitting the strings and replacing the spaces or special characters

# %%
wordcloud_50(creator_analyst['Creators role-Analyst'], extra_stopwords=['tool','make','analysis', 'better', 'more', 'software', 'tools', 'user', 'step', 'users', 'use', 'image', 'don', 't', 's', 'etc', 
                 'used', 'clearly', 'doesn', 'best', 'touch', 'give', 'non', 'less', 'images', 'asap', 'high','using', 'well', 'work', 'even', 'end',
                 'others','everyone','everything','know','really','without','something','always','one','want', 'exactly', 've','m','certain', 're','instead',
                 'us','maybe','sc', 'kind','going', 'different','see','especially', 'lack','much', 'past', 'selves', 'running', 'either','require', 'happens', 'lot', 'put', 'perhaps', 
                 'properly', 'many', 'behave', 'good', 'data', 'away', 'tell', 'will', 'd'])
# Out:
# c:\Users\ssivagur\Documents\GitHub\2023_ImageAnalysisSurvey\notebooks\utils.py:294: FutureWarning: The default value of regex will change from True to False in a future version.
#   input = ''.join(series.str.lower().str.split().dropna(how='all').astype(str).str.replace(r'[-./?!,":;()\']',' ')) #splitting the strings and replacing the spaces or special characters

# %% [markdown]
# ##### Users role - Imaging

# %%
wordcloud_50(user_role_imaging["Users role - Imaging"], extra_stopwords=['tool','make','analysis', 'better', 'more', 'software', 'tools', 'user', 'step', 'users', 'use', 'don', 'image', 'imaging', 'images', 
                  'data', 'think', 'best', 'need', 'encourage', 'etc', 't', 'needs', 'basic', 'able', 'keep', 'used', 'help', 'high', 'try', 'first', 'clearly',
                  'bit', 'will', 'different', 'field', 'non', 'ask'])
# Out:
# c:\Users\ssivagur\Documents\GitHub\2023_ImageAnalysisSurvey\notebooks\utils.py:294: FutureWarning: The default value of regex will change from True to False in a future version.
#   input = ''.join(series.str.lower().str.split().dropna(how='all').astype(str).str.replace(r'[-./?!,":;()\']',' ')) #splitting the strings and replacing the spaces or special characters

# %% [markdown]
# ##### Users role -balanced

# %%
wordcloud_50(user_role_balanced["Users role-Balanced"], extra_stopwords=['tool','make','analysis', 'better', 'more', 'software', 'tools', 'user', 'step', 'users', 'use', 'don', 'image', 'imaging', 'images', 
                  'data', 'think', 'best', 'need', 'encourage', 'etc', 't', 'needs', 'basic', 'able', 'keep', 'used', 'help', 'high', 'try', 'first', 'clearly',
                  'bit', 'will', 'different', 'field', 'non', 'ask'])
# Out:
# c:\Users\ssivagur\Documents\GitHub\2023_ImageAnalysisSurvey\notebooks\utils.py:294: FutureWarning: The default value of regex will change from True to False in a future version.
#   input = ''.join(series.str.lower().str.split().dropna(how='all').astype(str).str.replace(r'[-./?!,":;()\']',' ')) #splitting the strings and replacing the spaces or special characters

# %% [markdown]
# ##### Users role - analyst

# %%
wordcloud_50(user_role_analyst["Users role - Analyst"], extra_stopwords=['tool','make','analysis', 'better', 'more', 'software', 'tools', 'user', 'step', 'users', 'use', 'don', 'image', 'imaging', 'images', 
                  'data', 'think', 'best', 'need', 'encourage', 'etc', 't', 'needs', 'basic', 'able', 'keep', 'used', 'help', 'high', 'try', 'first', 'clearly',
                  'bit', 'will', 'different', 'field', 'non', 'ask'])
# Out:
# c:\Users\ssivagur\Documents\GitHub\2023_ImageAnalysisSurvey\notebooks\utils.py:294: FutureWarning: The default value of regex will change from True to False in a future version.
#   input = ''.join(series.str.lower().str.split().dropna(how='all').astype(str).str.replace(r'[-./?!,":;()\']',' ')) #splitting the strings and replacing the spaces or special characters

# %% [markdown]
# ##### Making bar charts from the Creator and User replies - categorized based on worktype

# %%
def ngrams_test(series, range=()):
    """
    Creates a csv file of unigrams/bigrams/trigrams and their frequency of occurence.
    Parameters
    series:pd.Series. A dataframe column to be given as input
    range:tuple. If unigrams are expected then (1,1) is given as the parameter and for bigrams (2,2) is given as the parameter. If a mixture of unigrams and bigrams are expected then (1,2) can be given as the parameter.
    name: filename for the csv.
    """
    series = series.dropna()
    c_vec = CountVectorizer(stop_words='english', ngram_range=range)
    ngrams = c_vec.fit_transform(series)        # matrix of ngrams
    count_values = ngrams.toarray().sum(axis=0)  # count frequency of ngrams
    vocab = c_vec.vocabulary_       #creates a dictionary of the 'words' as the key and the position as 'values'
    df = pd.DataFrame(sorted([(count_values[i],k) for k,i in vocab.items()], reverse=True)).rename(columns={0: 'frequency', 1:'ngram'})       # list of ngrams
    #df.to_csv(name + '.csv')
    return df

# %% [markdown]
# ### Unigrams

# %% [markdown]
# ##### Imaging

# %%
creator_imaging_unigrams = ngrams_test(creator_imaging["Creators role-Imaging"], range=(1,1))

# %%
creator_imaging_unigrams.head(10)
# Out:
#    frequency          ngram
# 0          8          users
# 1          8          tools
# 2          7           user
# 3          6      tutorials
# 4          6  documentation
# 5          5           good
# 6          5       friendly
# 7          5         better
# 8          4          video
# 9          4        plugins

# %% [markdown]
# ##### Balanced

# %%
creator_balanced_unigrams = ngrams_test(creator_balanced['Creators role- Balanced'], range=(1,1))

# %%
creator_balanced_unigrams.head(10)
# Out:
#    frequency      ngram
# 0         38      tools
# 1         33   software
# 2         31       make
# 3         27      users
# 4         26        use
# 5         24     better
# 6         23  tutorials
# 7         23   analysis
# 8         22       step
# 9         20       open

# %% [markdown]
# ##### Analyst

# %%
creator_analyst_unigrams = ngrams_test(creator_analyst['Creators role-Analyst'], range=(1,1))

# %%
creator_analyst_unigrams.head(10)
# Out:
#    frequency          ngram
# 0         16          tools
# 1         13       software
# 2         10  documentation
# 3         10       analysis
# 4          8           step
# 5          8          image
# 6          8         better
# 7          7          users
# 8          6           code
# 9          5           user

# %% [markdown]
# ### Bigrams

# %% [markdown]
# ##### Imaging

# %%
creator_imaging_ngrams = ngrams_test(creator_imaging["Creators role-Imaging"], range=(2,2))

# %%
len(creator_imaging["Creators role-Imaging"])
# Out:
# 34

# %%
creator_imaging_ngrams.head(10)
# Out:
#    frequency            ngram
# 0          4  video tutorials
# 1          4    user friendly
# 2          2   user interface
# 3          2      open source
# 4          2    make analysis
# 5          2    friendly guis
# 6          1      won broadly
# 7          1   websites video
# 8          1      videos good
# 9          1          ve read

# %%
def customwrap(s,width=15):
    return "<br>".join(textwrap.wrap(s,width=width))

# %%
def wordcount_barchart(data, title='', total=()):
    wordcount_df = data.filter(items=list(range(0,10)), axis=0)
    fig = px.bar(y=wordcount_df['ngram'].map(customwrap), x=wordcount_df['frequency'],orientation='h', labels={'x':'frequency', 'y':''}, text_auto=True)
    fig.update_layout(width=500, height=600, title_y=0.95, font=dict(family='Helvetica', color="Black", size=16), legend=dict(title_font_family = 'Helvetica', font=dict(size=16, color="Black")))
    fig.update_yaxes(categoryorder='total ascending')
    fig.update_layout(title=title, title_x=0.5)
    fig.add_annotation(text="Total number of respondents = " + str(len(total)),xref="paper", yref="paper",x=0.5, y=1.05, showarrow=False)
    fig.write_image(title+'.svg')
    return fig

# %%
wordcount_barchart(creator_imaging_ngrams, title='Creators role-Imaging', total=creator_imaging["Creators role-Imaging"])

# %% [markdown]
# ##### Balanced

# %%
creator_balanced_ngrams = ngrams_test(creator_balanced['Creators role- Balanced'], range=(2,2))

# %%
len(creator_balanced['Creators role- Balanced'])
# Out:
# 158

# %%
creator_balanced_ngrams.head(10)
# Out:
#    frequency                 ngram
# 0         12           open source
# 1         10             step step
# 2          9         user friendly
# 3          5        image analysis
# 4          4       video tutorials
# 5          4              easy use
# 6          4  better documentation
# 7          3            tools easy
# 8          3        step tutorials
# 9          3       source software

# %%
wordcount_barchart(creator_balanced_ngrams, title='Creators role-Balanced', total=creator_balanced['Creators role- Balanced'])

# %% [markdown]
# ##### Analyst

# %%
creator_analyst_ngrams = ngrams_test(creator_analyst['Creators role-Analyst'], range=(2,2))

# %%
len(creator_analyst['Creators role-Analyst'])
# Out:
# 45

# %%
creator_analyst_ngrams.head(10)
# Out:
#    frequency                 ngram
# 0          5        image analysis
# 1          4             step step
# 2          3  better documentation
# 3          2        user interface
# 4          2             use cases
# 5          2              try make
# 6          2      standalone tools
# 7          2             long term
# 8          2              image sc
# 9          2        graphical user

# %%
wordcount_barchart(creator_analyst_ngrams, title='Creators role-Analyst', total = creator_analyst['Creators role-Analyst'])

# %% [markdown]
# ### Users role

# %% [markdown]
# ##### Imaging

# %%
user_imaging_bigram = ngrams_test(user_role_imaging["Users role - Imaging"], range=(2,2))

# %%
wordcount_barchart(user_imaging_bigram, title='Users role-Imaging', total=user_role_imaging["Users role - Imaging"])

# %% [markdown]
# ##### Balanced

# %%
user_balanced_bigram = ngrams_test(user_role_balanced["Users role-Balanced"], range=(2,2))

# %%
wordcount_barchart(user_balanced_bigram, title='Users role-Balanced', total=user_role_balanced["Users role-Balanced"])

# %% [markdown]
# ##### Analyst

# %%
user_analyst_bigram = ngrams_test(user_role_analyst["Users role - Analyst"], range=(2,2))

# %%
wordcount_barchart(user_analyst_bigram, title='Users role-Analyst', total=user_role_analyst["Users role - Analyst"])
